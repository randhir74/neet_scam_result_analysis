# %%
import os
import re
import requests
import pandas as pd
import pypdf
from pypdf import PdfReader, PdfWriter
import ipywidgets as widgets
from IPython.display import HTML
from io import StringIO

# %%
def print_df(df):
    a3 = widgets.HTML(layout={"scroll": "auto", "height": "500px"})
    a3.value = df.to_html(notebook=True)
    display(a3)

# %%
def download_pdf_file(url: str) -> bool:
    """Download PDF from given URL to local directory.

    :param url: The url of the PDF file to be downloaded
    :return: True if PDF file was successfully downloaded, otherwise False.
    """

    # Request URL and get response object
    response = requests.get(url, stream=True)

    # isolate PDF filename from URL
    pdf_file_name = os.path.basename(url)
    if response.status_code == 200:
        # Save in current working directory
        filepath = os.path.join(os.getcwd() + "/centre_results/" , pdf_file_name)
        print(filepath)
        with open(filepath, 'wb') as pdf_object:
            pdf_object.write(response.content)
            print(f'{pdf_file_name} was successfully saved!')
            return True
    else:
        print(f'Uh oh! Could not download {pdf_file_name},')
        print(f'HTTP response status code: {response.status_code}')
        return False

# %%
def save_data_for_one_centre(centre_code=110101):
    url = "https://neetfs.ntaonline.in/NEET_2024_Result/" + str(centre_code) + ".pdf"
    print("downloading data for centre code " + str(centre_code))
    download_pdf_file(url)
    print("file downloaded")

# %%
def save_data_for_one_centre(centre_code=110101):
    url = "https://neetfs.ntaonline.in/NEET_2024_Result/" + str(centre_code) + ".pdf"
    print("downloading data for centre code " + str(centre_code))
    download_pdf_file(url)
    print("file downloaded")

# %%
def read_html_with_read_html(file_path):
    # Read HTML file into DataFrame using read_html()
    # file_path = "/home/randhir/Desktop/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_1.html"
    # file_path = "https://neet.ntaonline.in/frontend/web/common-scorecard/index"

    # Use pd.read_html to read the table
    print(file_path)
    try:
        # Since pd.read_html returns a list of DataFrames, we get the first one [0]
        df = pd.read_html(file_path)[0]

        # Display the first few rows of the DataFrame
        print(df.head())
        return df
    except ValueError as e:
        print("Error:", e)
        print("No tables found in the HTML file. Please check the structure of your HTML.")
   

def read_html_file_n(n=1):
    html_path = f"/home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_{n}.html"
    return read_html_with_read_html(html_path)

# %%
centre_serial_df = []

for i in range(1,11):
    filei = read_html_file_n(i)
    centre_serial_df.append(filei)
    # print(f"i = {i}, ispresent = {filei[filei['CENTER NO.']==460712]}")
# Out:
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_1.html
#    Sr.No.                      CENTER STATE CENTER CITY  \
# 0       1  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1       2  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2       3  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3       4                    ANDHRA PRADESH      GUNTUR
# 4       5                    ANDHRA PRADESH      GUNTUR
#
#                                 CENTER NAME  CENTER NO.   View Result
# 0                  KENDRIYA VIDYALAYA NO. 1      110101  View Details
# 1   DR B R AMBEDKAR INSTITUTE OF TECHNOLOGY      110102  View Details
# 2  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL      110103  View Details
# 3       LITTLE FLOWER ENGLISH MEDIUM SCHOOL      120101  View Details
# 4        CHALAPATHI INSTITUTE OF TECHNOLOGY      120102  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_2.html
#    Sr.No.  CENTER STATE CENTER CITY                              CENTER NAME  \
# 0     501  CHHATTISGARH      RAIPUR                    KRISHNA PUBLIC SCHOOL
# 1     502  CHHATTISGARH      RAIPUR          HOLY HEARTS EDUCATIONAL ACADEMY
# 2     503  CHHATTISGARH      RAIPUR                   MAHARISHI VIDYA MANDIR
# 3     504  CHHATTISGARH      RAIPUR  HOLY CROSS SENIOR SECONDARY SCHOOL KAPA
# 4     505  CHHATTISGARH      RAIPUR               DELHI PUBLIC SCHOOL RAIPUR
#
#    CENTER NO.   View Result
# 0      170301  View Details
# 1      170302  View Details
# 2      170303  View Details
# 3      170304  View Details
# 4      170305  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_3.html
#    Sr.No. CENTER STATE CENTER CITY                                CENTER NAME  \
# 0    1001      HARYANA       SIRSA  VIVEKANAND BAL MANDIR SR SEC SCHOOL SIRSA
# 1    1002      HARYANA       SIRSA                           THE SIRSA SCHOOL
# 2    1003      HARYANA       SIRSA             AV INTERNATIONAL PUBLIC SCHOOL
# 3    1004      HARYANA       SIRSA                      GEETA SR. SEC. SCHOOL
# 4    1005      HARYANA     SONIPAT            JAIN VIDYA MANDIR SR SEC SCHOOL
#
#    CENTER NO.   View Result
# 0      231703  View Details
# 1      231704  View Details
# 2      231705  View Details
# 3      231706  View Details
# 4      231801  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_4.html
#    Sr.No. CENTER STATE    CENTER CITY                   CENTER NAME  \
# 0    1501    KARNATAKA  CHIKABALLAPUR  SBGNS RURAL COMP. PU COLLEGE
# 1    1502    KARNATAKA  CHIKABALLAPUR             BGS PUBLIC SCHOOL
# 2    1503    KARNATAKA  CHIKABALLAPUR                 VIKAS COLLEGE
# 3    1504    KARNATAKA  CHIKABALLAPUR     SBGN RURAL ENGLISH SCHOOL
# 4    1505    KARNATAKA  CHIKABALLAPUR  BHAIRAVESHWARA VIDYA SAMSTHE
#
#    CENTER NO.   View Result
# 0      271504  View Details
# 1      271505  View Details
# 2      271506  View Details
# 3      271507  View Details
# 4      271508  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_5.html
#    Sr.No.    CENTER STATE CENTER CITY                           CENTER NAME  \
# 0    2001  MADHYA PRADESH     VIDISHA     SAKET MGM SENIOR SECONDARY SCHOOL
# 1    2002  MADHYA PRADESH     VIDISHA  SAMRAT ASHOK TECHNOLOGICAL INSTITUTE
# 2    2003  MADHYA PRADESH     VIDISHA         MAGADHAM INTERNATIONAL SCHOOL
# 3    2004  MADHYA PRADESH      INDORE                NATIONAL PUBLIC SCHOOL
# 4    2005  MADHYA PRADESH      INDORE          VEDANSH INTERNATIONAL SCHOOL
#
#    CENTER NO.   View Result
# 0      303101  View Details
# 1      303102  View Details
# 2      303103  View Details
# 3      300351  View Details
# 4      300352  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_6.html
#    Sr.No. CENTER STATE CENTER CITY  \
# 0    2501  MAHARASHTRA     JALGAON
# 1    2502  MAHARASHTRA     JALGAON
# 2    2503  MAHARASHTRA     JALGAON
# 3    2504  MAHARASHTRA     JALGAON
# 4    2505  MAHARASHTRA     JALGAON
#
#                                          CENTER NAME  CENTER NO.   View Result
# 0           BOHRA CENTRAL SCHOOL JALGAON MAHARASHTRA      310702  View Details
# 1  K.C.E.SOCIETYS INSTITUTE OF MANAGEMENT & RESEA...      310703  View Details
# 2       VARDHAMAN UNIVERSE ACADEMY SHIVAR JALGAON MR      310704  View Details
# 3                         PODAR INTERNATIONAL SCHOOL      310705  View Details
# 4                 L.H.PATIL ENGLISH MEDIUM SCHOOL MH      310706  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_7.html
#    Sr.No. CENTER STATE CENTER CITY  \
# 0    3001       PUNJAB    BHATINDA
# 1    3002       PUNJAB    BHATINDA
# 2    3003       PUNJAB    BHATINDA
# 3    3004       PUNJAB    BHATINDA
# 4    3005       PUNJAB    BHATINDA
#
#                                         CENTER NAME  CENTER NO.   View Result
# 0                              POLICE PUBLIC SCHOOL      380202  View Details
# 1                   R.B.D.A.V.SR.SEC. PUBLIC SCHOOL      380203  View Details
# 2  SANAWAR AN INSTT FOR CHILDREN MALOUT RD BATHINDA      380204  View Details
# 3   ST XAVIER`S SCHOOL MODEL TOWN PH-II BHATINDA PB      380205  View Details
# 4                               DELHI PUBLIC SCHOOL      380206  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_8.html
#    Sr.No. CENTER STATE CENTER CITY  \
# 0    3501   TAMIL NADU     CHENNAI
# 1    3502   TAMIL NADU     CHENNAI
# 2    3503   TAMIL NADU     CHENNAI
# 3    3504   TAMIL NADU     CHENNAI
# 4    3505   TAMIL NADU     CHENNAI
#
#                                       CENTER NAME  CENTER NO.   View Result
# 0           ASAN MEMORIAL SENIOR SECONDARY SCHOOL      410108  View Details
# 1              SRM VALLIAMMAI ENGINEERING COLLEGE      410109  View Details
# 2   KRM PUBLIC SCHOOL SEMBIUM PERMABUR CHENNAI TN      410110  View Details
# 3      LALAJI MEMORIAL OMEGA INTERNATIONAL SCHOOL      410111  View Details
# 4  S P D H SINDHI MODEL S S SCHOOL KELLYS CHENNAI      410112  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_9.html
#    Sr.No.   CENTER STATE CENTER CITY  \
# 0    4001  UTTAR PRADESH    MIRZAPUR
# 1    4002  UTTAR PRADESH    MIRZAPUR
# 2    4003  UTTAR PRADESH    MIRZAPUR
# 3    4004  UTTAR PRADESH    MIRZAPUR
# 4    4005  UTTAR PRADESH   MORADABAD
#
#                                        CENTER NAME  CENTER NO.   View Result
# 0                          DAFFODILS PUBLIC SCHOOL      444801  View Details
# 1                       G. D. BINANI P. G. COLLEGE      444802  View Details
# 2  VARDHMAN PUBLIC SCHOOL, MUSSAFFARGANJ, MIRZAPUR      444803  View Details
# 3                           LIONS SCHOOL LAL DIGGI      444804  View Details
# 4                            CL GUPTA WORLD SCHOOL      444901  View Details
# /home/randhir/Desktop/DS_Projects/neet_result_analysis/HTML/neet_scam_data_result/Common_Scorecard_10.html
#    Sr.No. CENTER STATE CENTER CITY                                CENTER NAME  \
# 0    4501  UTTARAKHAND    HALDWANI                    CYNTHIA SR. SEC. SCHOOL
# 1    4502  UTTARAKHAND    HALDWANI  UNIVERSAL CONVENT SENIOR SECONDARY SCHOOL
# 2    4503  UTTARAKHAND     ROORKEE  ANAND SWAROOP ARYA SARASWATI VIDYA MANDIR
# 3    4504  UTTARAKHAND     ROORKEE                   SCHOLARS ACADEMY ROORKEE
# 4    4505  UTTARAKHAND     ROORKEE                     GREENWAY MODERN SCHOOL
#
#    CENTER NO.   View Result
# 0      450207  View Details
# 1      450208  View Details
# 2      450301  View Details
# 3      450302  View Details
# 4      450303  View Details

# %%
all_centres = pd.concat(centre_serial_df)
all_centres.rename(columns = {'Sr.No.':'centre_serial_no', 'CENTER STATE' : 'state', 'CENTER CITY' : 'city', 'CENTER NAME' : 'center_name', 'CENTER NO.' : 'center_no'}, inplace = True)

# %%
all_centres.to_parquet('all_centres.parquet', compression='gzip')

# %%
print(f"no of rows in all_centres = {all_centres['center_no'].count()}")
print(f"no of unique centres = {all_centres['center_no'].nunique()}")
# all_centres['center_no'].value_counts()
# all_centres[all_centres['center_no']==460712]
# Out:
# no of rows in all_centres = 4750
# no of unique centres = 4750

# %%
centre_codes = all_centres['center_no'].tolist()

# %%
centre_codes
# Out:
# [110101,
#  110102,
#  110103,
#  120101,
#  120102,
#  120103,
#  120104,
#  120105,
#  120106,
#  120107,
#  120108,
#  120201,
#  120202,
#  120203,
#  120204,
#  120205,
#  120206,
#  120207,
#  120301,
#  120302,
#  120303,
#  120304,
#  120305,
#  120401,
#  120402,
#  120403,
#  120404,
#  120405,
#  120406,
#  120407,
#  120408,
#  120409,
#  120501,
#  120502,
#  120503,
#  120504,
#  120505,
#  120506,
#  120507,
#  120508,
#  120509,
#  120510,
#  120511,
#  120512,
#  120513,
#  120514,
#  120515,
#  120516,
#  120517,
#  120518,
#  120519,
#  122301,
#  122302,
#  122401,
#  122402,
#  122403,
#  122404,
#  122405,
#  122406,
#  122407,
#  122408,
#  122501,
#  122502,
#  122503,
#  122504,
#  122505,
#  122701,
#  122801,
#  122802,
#  122803,
#  122901,
#  122902,
#  122903,
#  122904,
#  122905,
#  120520,
#  120521,
#  120522,
#  120523,
#  120524,
#  120525,
#  153405,
#  153406,
#  153407,
#  153408,
#  153501,
#  153502,
#  150101,
#  150102,
#  150103,
#  150104,
#  150105,
#  150106,
#  150107,
#  150108,
#  150201,
#  150202,
#  150203,
#  150204,
#  150205,
#  150206,
#  150207,
#  150208,
#  150209,
#  150210,
#  150211,
#  150212,
#  150213,
#  150214,
#  150215,
#  150216,
#  150217,
#  150218,
#  150219,
#  150220,
#  150221,
#  150222,
#  150223,
#  150224,
#  150225,
#  150226,
#  150227,
#  150228,
#  150229,
#  150230,
#  150231,
#  150232,
#  150233,
#  150234,
#  150235,
#  150236,
#  150237,
#  150238,
#  150239,
#  150240,
#  150241,
#  150242,
#  150243,
#  150244,
#  150245,
#  150246,
#  150247,
#  150248,
#  150249,
#  150250,
#  150251,
#  151602,
#  151603,
#  151604,
#  151605,
#  151606,
#  151607,
#  151608,
#  151609,
#  151610,
#  151701,
#  151702,
#  151801,
#  151802,
#  151803,
#  151804,
#  151805,
#  151806,
#  151807,
#  151808,
#  151809,
#  151810,
#  151811,
#  151812,
#  151813,
#  151814,
#  151901,
#  151902,
#  151903,
#  151904,
#  151905,
#  151906,
#  152001,
#  152101,
#  152102,
#  152201,
#  152202,
#  152203,
#  152204,
#  152205,
#  152301,
#  152302,
#  152303,
#  152401,
#  152501,
#  152502,
#  152503,
#  152504,
#  152601,
#  152602,
#  152603,
#  152604,
#  152605,
#  152606,
#  152607,
#  152608,
#  152609,
#  152610,
#  152701,
#  152702,
#  152801,
#  152802,
#  152803,
#  152804,
#  152805,
#  152806,
#  152807,
#  152808,
#  160101,
#  160102,
#  160103,
#  160104,
#  170101,
#  170102,
#  170103,
#  170104,
#  170105,
#  170106,
#  170107,
#  170108,
#  170109,
#  170110,
#  170111,
#  170112,
#  170113,
#  170114,
#  170115,
#  170201,
#  170202,
#  170203,
#  170204,
#  170205,
#  170206,
#  170207,
#  170208,
#  170209,
#  170210,
#  170211,
#  170212,
#  170213,
#  170214,
#  170215,
#  170301,
#  170302,
#  170303,
#  170304,
#  170305,
#  170306,
#  170307,
#  170308,
#  170309,
#  170310,
#  170311,
#  170312,
#  170313,
#  170314,
#  170315,
#  170316,
#  170317,
#  170401,
#  170402,
#  170403,
#  170404,
#  170405,
#  170406,
#  170407,
#  170408,
#  170409,
#  170410,
#  170501,
#  170502,
#  170601,
#  170701,
#  170702,
#  170801,
#  170802,
#  170901,
#  170902,
#  170903,
#  171001,
#  171002,
#  171003,
#  171101,
#  171102,
#  171103,
#  171201,
#  171202,
#  171301,
#  171302,
#  171303,
#  171401,
#  171402,
#  171403,
#  171404,
#  171501,
#  171601,
#  171602,
#  171603,
#  171604,
#  171605,
#  171701,
#  171702,
#  171703,
#  171704,
#  171705,
#  171706,
#  171801,
#  171901,
#  180101,
#  180102,
#  180103,
#  180104,
#  190101,
#  190201,
#  200101,
#  200102,
#  200103,
#  200104,
#  200105,
#  200106,
#  200107,
#  200108,
#  200109,
#  200110,
#  200111,
#  200112,
#  200113,
#  200114,
#  200115,
#  220910,
#  220911,
#  220912,
#  220913,
#  220914,
#  221001,
#  221002,
#  221003,
#  221004,
#  221005,
#  221006,
#  221007,
#  221101,
#  221102,
#  221103,
#  221201,
#  221202,
#  221203,
#  221204,
#  221301,
#  221302,
#  221303,
#  221401,
#  221402,
#  221403,
#  221404,
#  221405,
#  221406,
#  221407,
#  221408,
#  221409,
#  221410,
#  221411,
#  221412,
#  221413,
#  221414,
#  221501,
#  221502,
#  221503,
#  221504,
#  221505,
#  221601,
#  221701,
#  221702,
#  221703,
#  221704,
#  221705,
#  230101,
#  230102,
#  230103,
#  230104,
#  230105,
#  230106,
#  230107,
#  230108,
#  230109,
#  230110,
#  230111,
#  230112,
#  230113,
#  230114,
#  230115,
#  230116,
#  230201,
#  230202,
#  230203,
#  230204,
#  230205,
#  230206,
#  230207,
#  230208,
#  230209,
#  230210,
#  230301,
#  230302,
#  230303,
#  230304,
#  230305,
#  230401,
#  230402,
#  230403,
#  230404,
#  230405,
#  230406,
#  230501,
#  230502,
#  230503,
#  230504,
#  230505,
#  230506,
#  230507,
#  230601,
#  230602,
#  230603,
#  230604,
#  230605,
#  230606,
#  230607,
#  230608,
#  230609,
#  230610,
#  230611,
#  230612,
#  230613,
#  230614,
#  230701,
#  230702,
#  230703,
#  230801,
#  230802,
#  230803,
#  230804,
#  230901,
#  230902,
#  230903,
#  230904,
#  231001,
#  231002,
#  231003,
#  231004,
#  231101,
#  231102,
#  231103,
#  231104,
#  231105,
#  231201,
#  231202,
#  231203,
#  231204,
#  231301,
#  231302,
#  231303,
#  231304,
#  231305,
#  231306,
#  231307,
#  231401,
#  231402,
#  231403,
#  231404,
#  231501,
#  231502,
#  231503,
#  231504,
#  231505,
#  231506,
#  231507,
#  231508,
#  231509,
#  231601,
#  231602,
#  231603,
#  231604,
#  231605,
#  231606,
#  231607,
#  231608,
#  231701,
#  231702,
#  ...]

# %%
for cc in centre_codes:
    fp = f"/home/randhir/Desktop/DS_Projects/neet_result_analysis/centre_results/{cc}.pdf"
    if not os.path.isfile(fp):
        print(f"file doesnt exist for centre code : {cc}")
        save_data_for_one_centre(cc)

# %%
def parse_center_result(cc = 121202):
    pdf_path = f"centre_results/{cc}.pdf"
    reader = PdfReader(pdf_path)
    
    page = reader.pages[0]
    texts = page.extract_text()
    # print(texts)
    
    start_idx = [m.start() for m in re.finditer('Srlno. Marks', texts)]
    print("start_idx: ", start_idx)
    print("texts: ", texts)
    results_cc = []
    
    for i in range(1, len(start_idx)):
        idx = start_idx[i-1]
        idx_1 = start_idx[i]
        results = []
        fno = None
        
        for x in texts[idx+15:idx_1].split(" "):
            print(x, ' ')
            if x=="":
                continue
            x = int(x)
            if fno==None:
                fno = x
            else:
                results.append((fno,x))
                fno = None
        results_cc.extend(results)
    df = pd.DataFrame(results_cc, columns=['roll_no', 'marks'])
    # print(df.head(5))
    df['center_no'] = cc
    # print(df.head(5))
    df['roll_no_cc'] = cc*10000 + df['roll_no'] 
    # print(df.head(5))
    return df
